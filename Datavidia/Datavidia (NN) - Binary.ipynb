# %%
import pandas as pd

train_dataset = pd.read_csv('/content/drive/MyDrive/Datavidia/train_dataset_advanced_large.csv', index_col=0)
Y_training_df = train_dataset["main-label"]
# Drop 'label' column
X_training_df = train_dataset.drop(labels = ['main-label','main-id'],axis = 1) 
print('Y_train shape', Y_training_df.shape)
print('X_train shape', X_training_df.shape)
# Out:
# Y_train shape (18570,)
# X_train shape (18570, 15408)

# %%
import numpy as np

X_training = X_training_df.values
Y_training = Y_training_df.values

# Split the train and the validation set for the fitting
from sklearn.model_selection import train_test_split
X_train, X_val, Y_train, Y_val = train_test_split(X_training, Y_training, test_size = 0.1)
print("x_train shape",X_train.shape)
print("x_val shape",X_val.shape)
print("y_train shape",Y_train.shape)
print("y_val shape",Y_val.shape)
# Out:
# x_train shape (16713, 15408)
# x_val shape (1857, 15408)
# y_train shape (16713,)
# y_val shape (1857,)

# %%
# from keras.utils.np_utils import to_categorical # convert to one-hot-encoding
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from tensorflow_addons.metrics import F1Score
model = Sequential()

model.add(Dense(1, activation='sigmoid',input_shape=(15408,)))

# Define the optimizer
optimizer = Adam(lr=0.001)
# Compile the model
model.compile(optimizer = optimizer , loss = "binary_crossentropy", metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1)                 15409
# =================================================================
# Total params: 15,409
# Trainable params: 15,409
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 50  # for better result increase the epochs
batch_size = 100
reduce_lr =  ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, min_delta=1e-4, mode='min',verbose=1)
checkpoint = ModelCheckpoint("/content/drive/MyDrive/Datavidia/model NN-binary (best val_acc).h5",
                             verbose=1, save_best_only=True, monitor='val_accuracy')
# Fit the model
history = model.fit(X_train, Y_train, 
                    epochs = epochs, 
                    validation_data = (X_val,Y_val), 
                    batch_size=batch_size,
                    callbacks=[checkpoint])
# Out:
# Epoch 1/50
# 168/168 [==============================] - 2s 9ms/step - loss: 0.5752 - accuracy: 0.8215 - val_loss: 0.4147 - val_accuracy: 0.8659
#
# Epoch 00001: val_accuracy improved from -inf to 0.86591, saving model to /content/drive/MyDrive/Datavidia/model NN-binary (best val_acc).h5
# Epoch 2/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.3873 - accuracy: 0.8799 - val_loss: 0.3469 - val_accuracy: 0.8934
#
# Epoch 00002: val_accuracy improved from 0.86591 to 0.89338, saving model to /content/drive/MyDrive/Datavidia/model NN-binary (best val_acc).h5
# Epoch 3/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.3256 - accuracy: 0.9038 - val_loss: 0.3044 - val_accuracy: 0.9203
#
# Epoch 00003: val_accuracy improved from 0.89338 to 0.92030, saving model to /content/drive/MyDrive/Datavidia/model NN-binary (best val_acc).h5
# Epoch 4/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.2774 - accuracy: 0.9250 - val_loss: 0.2739 - val_accuracy: 0.9295
#
# Epoch 00004: val_accuracy improved from 0.92030 to 0.92946, saving model to /content/drive/MyDrive/Datavidia/model NN-binary (best val_acc).h5
# Epoch 5/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.2546 - accuracy: 0.9346 - val_loss: 0.2518 - val_accuracy: 0.9348
#
# Epoch 00005: val_accuracy improved from 0.92946 to 0.93484, saving model to /content/drive/MyDrive/Datavidia/model NN-binary (best val_acc).h5
# Epoch 6/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.2291 - accuracy: 0.9434 - val_loss: 0.2346 - val_accuracy: 0.9375
#
# Epoch 00006: val_accuracy improved from 0.93484 to 0.93753, saving model to /content/drive/MyDrive/Datavidia/model NN-binary (best val_acc).h5
# Epoch 7/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.2130 - accuracy: 0.9490 - val_loss: 0.2213 - val_accuracy: 0.9397
#
# Epoch 00007: val_accuracy improved from 0.93753 to 0.93969, saving model to /content/drive/MyDrive/Datavidia/model NN-binary (best val_acc).h5
# Epoch 8/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.1986 - accuracy: 0.9522 - val_loss: 0.2106 - val_accuracy: 0.9413
#
# Epoch 00008: val_accuracy improved from 0.93969 to 0.94130, saving model to /content/drive/MyDrive/Datavidia/model NN-binary (best val_acc).h5
# Epoch 9/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.1800 - accuracy: 0.9586 - val_loss: 0.2017 - val_accuracy: 0.9440
#
# Epoch 00009: val_accuracy improved from 0.94130 to 0.94400, saving model to /content/drive/MyDrive/Datavidia/model NN-binary (best val_acc).h5
# Epoch 10/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.1754 - accuracy: 0.9568 - val_loss: 0.1944 - val_accuracy: 0.9456
#
# Epoch 00010: val_accuracy improved from 0.94400 to 0.94561, saving model to /content/drive/MyDrive/Datavidia/model NN-binary (best val_acc).h5
# Epoch 11/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.1656 - accuracy: 0.9600 - val_loss: 0.1883 - val_accuracy: 0.9461
#
# Epoch 00011: val_accuracy improved from 0.94561 to 0.94615, saving model to /content/drive/MyDrive/Datavidia/model NN-binary (best val_acc).h5
# Epoch 12/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.1560 - accuracy: 0.9617 - val_loss: 0.1830 - val_accuracy: 0.9467
#
# Epoch 00012: val_accuracy improved from 0.94615 to 0.94669, saving model to /content/drive/MyDrive/Datavidia/model NN-binary (best val_acc).h5
# Epoch 13/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.1534 - accuracy: 0.9624 - val_loss: 0.1786 - val_accuracy: 0.9483
#
# Epoch 00013: val_accuracy improved from 0.94669 to 0.94830, saving model to /content/drive/MyDrive/Datavidia/model NN-binary (best val_acc).h5
# Epoch 14/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.1450 - accuracy: 0.9640 - val_loss: 0.1749 - val_accuracy: 0.9488
#
# Epoch 00014: val_accuracy improved from 0.94830 to 0.94884, saving model to /content/drive/MyDrive/Datavidia/model NN-binary (best val_acc).h5
# Epoch 15/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.1419 - accuracy: 0.9625 - val_loss: 0.1716 - val_accuracy: 0.9494
#
# Epoch 00015: val_accuracy improved from 0.94884 to 0.94938, saving model to /content/drive/MyDrive/Datavidia/model NN-binary (best val_acc).h5
# Epoch 16/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.1338 - accuracy: 0.9653 - val_loss: 0.1686 - val_accuracy: 0.9494
#
# Epoch 00016: val_accuracy did not improve from 0.94938
# Epoch 17/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.1303 - accuracy: 0.9657 - val_loss: 0.1662 - val_accuracy: 0.9505
#
# Epoch 00017: val_accuracy improved from 0.94938 to 0.95046, saving model to /content/drive/MyDrive/Datavidia/model NN-binary (best val_acc).h5
# Epoch 18/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.1249 - accuracy: 0.9674 - val_loss: 0.1642 - val_accuracy: 0.9521
#
# Epoch 00018: val_accuracy improved from 0.95046 to 0.95207, saving model to /content/drive/MyDrive/Datavidia/model NN-binary (best val_acc).h5
# Epoch 19/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.1245 - accuracy: 0.9692 - val_loss: 0.1623 - val_accuracy: 0.9537
#
# Epoch 00019: val_accuracy improved from 0.95207 to 0.95369, saving model to /content/drive/MyDrive/Datavidia/model NN-binary (best val_acc).h5
# Epoch 20/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.1207 - accuracy: 0.9682 - val_loss: 0.1608 - val_accuracy: 0.9542
#
# Epoch 00020: val_accuracy improved from 0.95369 to 0.95423, saving model to /content/drive/MyDrive/Datavidia/model NN-binary (best val_acc).h5
# Epoch 21/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.1156 - accuracy: 0.9685 - val_loss: 0.1593 - val_accuracy: 0.9548
#
# Epoch 00021: val_accuracy improved from 0.95423 to 0.95477, saving model to /content/drive/MyDrive/Datavidia/model NN-binary (best val_acc).h5
# Epoch 22/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.1155 - accuracy: 0.9697 - val_loss: 0.1581 - val_accuracy: 0.9548
#
# Epoch 00022: val_accuracy did not improve from 0.95477
# Epoch 23/50
# 168/168 [==============================] - 1s 9ms/step - loss: 0.1121 - accuracy: 0.9703 - val_loss: 0.1573 - val_accuracy: 0.9553
#
# Epoch 00023: val_accuracy improved from 0.95477 to 0.95530, saving model to /content/drive/MyDrive/Datavidia/model NN-binary (best val_acc).h5
# Epoch 24/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.1087 - accuracy: 0.9720 - val_loss: 0.1564 - val_accuracy: 0.9553
#
# Epoch 00024: val_accuracy did not improve from 0.95530
# Epoch 25/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.1099 - accuracy: 0.9706 - val_loss: 0.1557 - val_accuracy: 0.9564
#
# Epoch 00025: val_accuracy improved from 0.95530 to 0.95638, saving model to /content/drive/MyDrive/Datavidia/model NN-binary (best val_acc).h5
# Epoch 26/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.1049 - accuracy: 0.9715 - val_loss: 0.1551 - val_accuracy: 0.9564
#
# Epoch 00026: val_accuracy did not improve from 0.95638
# Epoch 27/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.1046 - accuracy: 0.9716 - val_loss: 0.1546 - val_accuracy: 0.9564
#
# Epoch 00027: val_accuracy did not improve from 0.95638
# Epoch 28/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.1002 - accuracy: 0.9735 - val_loss: 0.1544 - val_accuracy: 0.9558
#
# Epoch 00028: val_accuracy did not improve from 0.95638
# Epoch 29/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.0982 - accuracy: 0.9741 - val_loss: 0.1540 - val_accuracy: 0.9564
#
# Epoch 00029: val_accuracy did not improve from 0.95638
# Epoch 30/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.0976 - accuracy: 0.9740 - val_loss: 0.1539 - val_accuracy: 0.9558
#
# Epoch 00030: val_accuracy did not improve from 0.95638
# Epoch 31/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.0940 - accuracy: 0.9746 - val_loss: 0.1536 - val_accuracy: 0.9558
#
# Epoch 00031: val_accuracy did not improve from 0.95638
# Epoch 32/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.0939 - accuracy: 0.9746 - val_loss: 0.1536 - val_accuracy: 0.9558
#
# Epoch 00032: val_accuracy did not improve from 0.95638
# Epoch 33/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.0968 - accuracy: 0.9742 - val_loss: 0.1536 - val_accuracy: 0.9558
#
# Epoch 00033: val_accuracy did not improve from 0.95638
# Epoch 34/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.0905 - accuracy: 0.9745 - val_loss: 0.1537 - val_accuracy: 0.9564
#
# Epoch 00034: val_accuracy did not improve from 0.95638
# Epoch 35/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.0883 - accuracy: 0.9760 - val_loss: 0.1538 - val_accuracy: 0.9564
#
# Epoch 00035: val_accuracy did not improve from 0.95638
# Epoch 36/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.0903 - accuracy: 0.9749 - val_loss: 0.1539 - val_accuracy: 0.9564
#
# Epoch 00036: val_accuracy did not improve from 0.95638
# Epoch 37/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.0854 - accuracy: 0.9778 - val_loss: 0.1541 - val_accuracy: 0.9558
#
# Epoch 00037: val_accuracy did not improve from 0.95638
# Epoch 38/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.0862 - accuracy: 0.9754 - val_loss: 0.1543 - val_accuracy: 0.9558
#
# Epoch 00038: val_accuracy did not improve from 0.95638
# Epoch 39/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.0847 - accuracy: 0.9768 - val_loss: 0.1546 - val_accuracy: 0.9553
#
# Epoch 00039: val_accuracy did not improve from 0.95638
# Epoch 40/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.0814 - accuracy: 0.9785 - val_loss: 0.1548 - val_accuracy: 0.9553
#
# Epoch 00040: val_accuracy did not improve from 0.95638
# Epoch 41/50
# 168/168 [==============================] - 1s 9ms/step - loss: 0.0858 - accuracy: 0.9766 - val_loss: 0.1552 - val_accuracy: 0.9548
#
# Epoch 00041: val_accuracy did not improve from 0.95638
# Epoch 42/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.0812 - accuracy: 0.9776 - val_loss: 0.1554 - val_accuracy: 0.9548
#
# Epoch 00042: val_accuracy did not improve from 0.95638
# Epoch 43/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.0785 - accuracy: 0.9784 - val_loss: 0.1559 - val_accuracy: 0.9542
#
# Epoch 00043: val_accuracy did not improve from 0.95638
# Epoch 44/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.0779 - accuracy: 0.9790 - val_loss: 0.1562 - val_accuracy: 0.9548
#
# Epoch 00044: val_accuracy did not improve from 0.95638
# Epoch 45/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.0733 - accuracy: 0.9808 - val_loss: 0.1565 - val_accuracy: 0.9553
#
# Epoch 00045: val_accuracy did not improve from 0.95638
# Epoch 46/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.0757 - accuracy: 0.9792 - val_loss: 0.1570 - val_accuracy: 0.9553
#
# Epoch 00046: val_accuracy did not improve from 0.95638
# Epoch 47/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.0749 - accuracy: 0.9803 - val_loss: 0.1574 - val_accuracy: 0.9542
#
# Epoch 00047: val_accuracy did not improve from 0.95638
# Epoch 48/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.0752 - accuracy: 0.9787 - val_loss: 0.1579 - val_accuracy: 0.9537
#
# Epoch 00048: val_accuracy did not improve from 0.95638
# Epoch 49/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.0745 - accuracy: 0.9783 - val_loss: 0.1583 - val_accuracy: 0.9537
#
# Epoch 00049: val_accuracy did not improve from 0.95638
# Epoch 50/50
# 168/168 [==============================] - 1s 8ms/step - loss: 0.0740 - accuracy: 0.9802 - val_loss: 0.1589 - val_accuracy: 0.9537
#
# Epoch 00050: val_accuracy did not improve from 0.95638

# %%
import matplotlib.pyplot as plt

# Plot the loss and accuracy curves for training and validation 
plt.plot(history.history['val_loss'], color='b', label="validation loss", linestyle=':')
plt.plot(history.history['loss'], color='b', label="loss", linestyle='-')
plt.plot(history.history['val_accuracy'], color='r', label="validation accuracy", linestyle=':')
plt.plot(history.history['accuracy'], color='r', label="accuracy", linestyle='-')
plt.title("Test Loss")
plt.xlabel("Number of Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# ### Test Section

# %%
from tensorflow.keras.models import load_model

model = load_model('/content/drive/MyDrive/Datavidia/model NN-binary (best val_acc).h5')

# %%
import pandas as pd

test_dataset = pd.read_csv('/content/drive/MyDrive/Datavidia/test_dataset_advanced.csv', index_col=0)
# Drop 'label' column
X_test = test_dataset.drop(labels = ['main-id'],axis = 1)
print('X_test shape', X_test.shape)
# Out:
# X_test shape (3714, 15408)

# %%
from copy import deepcopy
import numpy as np

def binary_classifier(label):
  temp = deepcopy(label)
  for i in temp:
    if i[0] > 0.5:
      i[0] = 1
    else:
      i[0] = 0
  return temp

# %%
# confusion matrix
import seaborn as sns
# Predict the values from the validation dataset
Y_pred = model.predict(X_test.values)
Y_pred_advanced = binary_classifier(Y_pred).astype(int)
# Y_pred_advanced = np.argmax(Y_pred,axis = 1)
Y_pred_advanced = Y_pred_advanced.reshape(-1)
print(Y_pred_advanced)
# Out:
# [0 0 0 ... 0 0 1]

# %%
temp1 = test_dataset['main-id'].values
test_result = list(zip(list(temp1),list(Y_pred_advanced)))
test_result_df = pd.DataFrame(test_result,columns=['review_id','category'])
test_result_df
# Out:
#                              review_id  category
# 0     7302180ac7160f04a405d8aa7bd6beb8         0
# 1     3184c670e170f565c7522eb76a320ba1         0
# 2     e33abf6bb5d5a9a77c339043b1725dc8         0
# 3     061d388950340070a6ac03fabc9027b0         0
# 4     e62d87c348674b6c06856964f3ab16b8         1
# ...                                ...       ...
# 3709  4fac4c272d9194021f921138ebd5b389         0
# 3710  4fabd4722dd4074841f9656f75105f09         0
# 3711  44ff89997547d54cccb2a33776181240         0
# 3712  c46cf84e3665a10199a539fee919edd6         0
# 3713  82d1677f2aa50eb79fb4e6f496384ef2         1
#
# [3714 rows x 2 columns]

# %%
test_result_df.to_csv('/content/drive/MyDrive/Datavidia/test_result-NN-binary.csv', index=False)

#0.2%test 95.6
