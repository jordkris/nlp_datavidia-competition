# %%
import pandas as pd

data = pd.read_csv('/content/drive/MyDrive/Datavidia/word_bank (ID).txt', sep="\n", header=None)
id_dict = data.values.flatten()
len(id_dict)
# Out:
# 288204

# %%
from scipy.stats import pearsonr

correlation, p_value = pearsonr([1,2,3], [1,2,10])
print('Correlation\t: ',correlation)
print('P-value\t\t: ',p_value)
# Out:
# Correlation	:  0.912245460839306
# P-value		:  0.26869415950618253

# %%
def id_spell_check(str_check, str_dict):
  for i in str_check.split(' '):
    corr = 0;
    for j in str_dict:
# Out:
# []
# kucing saye hitsm
